# %%
using Pkg;Pkg.activate(".")
# Out:
# Failed to start the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
include("view_relaxation.jl")
# Out:
# WARNING: could not import BPGates.T1BellDephaseOp into Main
# WARNING: could not import BPGates.T1DepolarizingOp into Main

# %%
plot_T1_results()
# plot_T2_results()
# plot_T1BellDephase_results()
# plot_T1Depolarizing_results()
# plot_all_noise_comparison()  # Compare all 4 noise types side by side
# plot_bell_state_comparison(T1NoiseOp, t -> λ₁_func(t, 100); op_name="T1")
# plot_bell_state_comparison(T2NoiseOp, t -> λ₂_func(t, 100, 150); op_name="T2")
# plot_bell_state_comparison(T1BellDephaseOp, t -> λ₁_func(t, 100); op_name="T1BellDephase")
# plot_bell_state_comparison(T1DepolarizingOp, t -> λ₁_func(t, 100); op_name="T1Depolarizing")
# wait(display(fig))

# %%
# plot_all_noise_comparison()

# %%
# plot_bell_state_comparison(T1BellDephaseOp, t -> λ₁_func(t, 100); op_name="T1BellDephase")
